# %% [markdown]
# # Data Cleaning - Pokémon Dataset
#
# Before starting any analysis, the dataset needs to be inspected and cleaned to ensure consistency and reliability.
#
# This step focuses on identifying missing values, removing unnecessary columns, and standardizing the dataset so it can be used for further analysis and modeling.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/pokemon.csv")
df.head()
# Out:
#    Unnamed: 0  ID        Name Type 1  Type 2 Ability 1 Ability 2  \
# 0           0   1   bulbasaur  grass  poison  overgrow       NaN
# 1           1   2     ivysaur  grass  poison  overgrow       NaN
# 2           2   3    venusaur  grass  poison  overgrow       NaN
# 3           3   4  charmander   fire     NaN     blaze       NaN
# 4           4   5  charmeleon   fire     NaN     blaze       NaN
#
#   Hidden Ability  HP  Attack  Defense  Special Attack  Special Defense  Speed  \
# 0    chlorophyll  45      49       49              65               65     45
# 1    chlorophyll  60      62       63              80               80     60
# 2    chlorophyll  80      82       83             100              100     80
# 3    solar-power  39      52       43              60               50     65
# 4    solar-power  58      64       58              80               65     80
#
#    Legendary  Mythical  Psuedo-Legendary
# 0      False     False             False
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        898 non-null    int64
#  1   ID                898 non-null    int64
#  2   Name              898 non-null    str
#  3   Type 1            898 non-null    str
#  4   Type 2            442 non-null    str
#  5   Ability 1         898 non-null    str
#  6   Ability 2         481 non-null    str
#  7   Hidden Ability    764 non-null    str
#  8   HP                898 non-null    int64
#  9   Attack            898 non-null    int64
#  10  Defense           898 non-null    int64
#  11  Special Attack    898 non-null    int64
#  12  Special Defense   898 non-null    int64
#  13  Speed             898 non-null    int64
#  14  Legendary         898 non-null    bool
#  15  Mythical          898 non-null    bool
#  16  Psuedo-Legendary  898 non-null    bool
# ...

# %% [markdown]
# ## Initial Data Inspection
#
# The dataset was first loaded and explored to understand its structure, data types, and potential issues.
#
# Key checks performed:
# - Overview of columns and data types
# - Identification of missing values
# - Detection of unnecessary or inconsistent columns
#
# At this stage, the goal was not to modify the data, but to observe and understand it.

# %%
df = df.drop(columns=["Unnamed: 0"])

# %% [markdown]
# ## Removing Irrelevant Columns
#
# The dataset contained an extra column named `Unnamed: 0`, which appears to be an index column from a previous export.
#
# Since it does not provide any meaningful information for analysis, it was removed to keep the dataset clean and focused.

# %%
df["Type 2"] = df["Type 2"].fillna("None")

# %% [markdown]
# ## Handling Missing Values
#
# The column `Type 2` contains missing values. This is expected because not all Pokémon have a secondary type.
#
# Instead of removing these rows or leaving them as null, the missing values were replaced with `"None"` to clearly indicate the absence of a second type.
#
# This helps maintain consistency and avoids issues during analysis and modeling.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Checking for Duplicate Records
#
# The dataset was checked for duplicate rows to ensure data integrity.
#
# If duplicates were found, they were removed to prevent skewed analysis. In this case, the dataset either contained no duplicates or they were handled accordingly.

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_")

# %% [markdown]
# ## Standardizing Column Names
#
# Column names were cleaned by:
# - Removing leading/trailing spaces
# - Replacing spaces with underscores
#
# This makes the column names easier to work with in code and avoids potential errors when referencing them.

# %%
df.to_csv("../data/cleaned/pokemon_cleaned.csv", index=False)

# %% [markdown]
# ## Saving the Cleaned Dataset
#
# After cleaning, the dataset was saved as a new file in the `data/cleaned/` directory.
#
# This ensures that:
# - The original raw data remains unchanged
# - All further analysis is performed on a consistent and prepared dataset

# %% [markdown]
# ## Key Observations After Data Cleaning
#
# After cleaning and inspecting the dataset, a few initial patterns and anomalies were observed:
#
# ### 1. Legendary, Mythical, and Pseudo-Legendary Columns
#
# All values in the `Legendary`, `Mythical`, and `Pseudo Legendary` columns appear to be `False`.
#
# This is unusual, as the dataset is expected to contain at least some Pokémon belonging to these categories. This may indicate:
# - Missing or incorrectly populated data
# - A preprocessing issue in the original dataset
#
# This will need further verification before using these columns for analysis or modeling.
#
# ---
#
# ### 2. Maximum Stat Values
#
# The maximum values observed for the base stats are:
#
# - HP: 255
# - Attack: 181
# - Defense: 230
# - Special Attack: 173
# - Special Defense: 230
# - Speed: 200
#
# These values indicate the upper limits of Pokémon capabilities in the dataset and suggest the presence of highly specialized or powerful Pokémon.
#
# ---
#
# ### 3. Minimum Stat Values
#
# The minimum values observed are:
#
# - HP: 1
# - Attack: 5
# - Defense: 5
# - Special Attack: 10
# - Special Defense: 20
# - Speed: 5
#
# This shows a wide range in stat distribution, from extremely weak to very strong Pokémon.
#
# Such variation makes the dataset suitable for comparative analysis and modeling.

# %%
df = df.rename(columns={"Psuedo-Legendary": "Pseudo_Legendary"})

# %%
df[['Legendary', 'Mythical', 'Pseudo_Legendary']].sum()
# Out:
# Legendary           57
# Mythical            22
# Pseudo_Legendary     9
# dtype: int64

# %%
df[['Legendary', 'Mythical', 'Pseudo_Legendary']].value_counts()
# Out:
# Legendary  Mythical  Pseudo_Legendary
# False      False     False               810
# True       False     False                57
# False      True      False                22
#            False     True                  9
# Name: count, dtype: int64

# %%
df = df.rename(columns={"Psuedo-Legendary": "Pseudo_Legendary"})

df.to_csv("../data/cleaned/pokemon_cleaned.csv", index=False)
